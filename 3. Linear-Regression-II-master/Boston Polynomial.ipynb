# %%
#import libraries
from sklearn.datasets import load_boston # dataset
import pandas as pd
import numpy as np
#import matplotlib.pyplot as plt
from statsmodels.stats.outliers_influence import variance_inflation_factor
from statsmodels.compat import lzip
import statsmodels.stats.api as sm
from sklearn.metrics import mean_squared_error
from math import sqrt
from sklearn.model_selection import train_test_split
import statsmodels as sm
import statsmodels.formula.api as smf
from sklearn import linear_model

# %matplotlib inline

# %%
# instantiate dataset and create DataFrame 
boston = load_boston()
df = pd.DataFrame(boston.data, columns=boston.feature_names)
df.head()
target = pd.DataFrame(boston.target, columns=["MEDV"])
#print(target)

# %%
# Basic exploratory analyses 
print("Rows,Columns:",df.shape)
df.describe()
# Out:
# Rows,Columns: (506, 13)
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.593761   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.596783   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.647423   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# std     28.148861    2.105710    8.707259  168.537116    2.164946   91.294864
# min      2.900000    1.129600    1.000000  187.000000   12.600000    0.320000
# 25%     45.025000    2.100175    4.000000  279.000000   17.400000  375.377500
# 50%     77.500000    3.207450    5.000000  330.000000   19.050000  391.440000
# 75%     94.075000    5.188425   24.000000  666.000000   20.200000  396.225000
# max    100.000000   12.126500   24.000000  711.000000   22.000000  396.900000
#
#             LSTAT
# count  506.000000
# mean    12.653063
# std      7.141062
# min      1.730000
# 25%      6.950000
# 50%     11.360000
# 75%     16.955000
# max     37.970000

# %%
# split dataset into training and testing set
X_train, X_test, Y_train, Y_test = train_test_split(df, target, test_size=0.30)

# %%
# Fitting using stats model
model_1 = smf.OLS(Y_train,X_train).fit()
prediction_1 = model_1.predict(X_train) # predict y_train values
prediction_2 = model_1.predict(X_test)# predict y_test values

# %%
model_1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   MEDV   R-squared:                       0.956
# Model:                            OLS   Adj. R-squared:                  0.955
# Method:                 Least Squares   F-statistic:                     573.6
# Date:                Sat, 13 Jan 2018   Prob (F-statistic):          1.01e-222
# Time:                        10:12:21   Log-Likelihood:                -1077.6
# No. Observations:                 354   AIC:                             2181.
# Df Residuals:                     341   BIC:                             2231.
# Df Model:                          13
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# CRIM          -0.1202      0.040     -2.992      0.003      -0.199      -0.041
# ZN             0.0550      0.017      3.158      0.002       0.021       0.089
# INDUS         -0.0629      0.081     -0.779      0.437      -0.222       0.096
# CHAS           3.6216      1.134      3.192      0.002       1.390       5.853
# NOX           -2.5308      4.233     -0.598      0.550     -10.858       5.796
# RM             5.7354      0.379     15.129      0.000       4.990       6.481
# AGE           -0.0092      0.017     -0.530      0.596      -0.043       0.025
# DIS           -0.9718      0.231     -4.210      0.000      -1.426      -0.518
# RAD            0.1512      0.079      1.914      0.056      -0.004       0.306
# TAX           -0.0068      0.005     -1.479      0.140      -0.016       0.002
# PTRATIO       -0.3217      0.138     -2.323      0.021      -0.594      -0.049
# B              0.0127      0.003      3.739      0.000       0.006       0.019
# LSTAT         -0.3669      0.060     -6.128      0.000      -0.485      -0.249
# ==============================================================================
# Omnibus:                      138.750   Durbin-Watson:                   1.835
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              833.874
# Skew:                           1.524   Prob(JB):                    8.44e-182
# Kurtosis:                       9.874   Cond. No.                     8.71e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 8.71e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# ## Looking at the Summary
#
# In the summary we see some interesting results. The INDUS coefficient (proportion of non-retail business acres per town) is not nearly statistically significant at the 5% or 10% level. The same goes for the AGE and NOX variables.
#
# There seems to be no autocorrelation (as expected as this is not a time-series problem).
#
# Overall, the Adjusted R^2 score is great, but how about RMSE (root mean square error), lets have a loo

# %%
rmse_training = sqrt(mean_squared_error(Y_train, prediction_1))
print("RMSE for training data:", rmse_training)
rmse_test = sqrt(mean_squared_error(Y_test,prediction_2))
print("RMSE for test data:", rmse_test)
# Out:
# RMSE for training data: 4.611418758222202
# RMSE for test data: 5.6805635320450865

# %% [markdown]
# Hmm... The RMSE for the test data is quite low and very close to that of the training data. But can we do better?! Lets try by doing a correlation test to identify spurious variables. **A VIF Test.**

# %%
vif = pd.DataFrame()
vif["VIF Factor"] = [variance_inflation_factor(X_test.values, i) for i in range(X_test.shape[1])]
vif["features"] = X_test.columns
vif
# Out:
#     VIF Factor features
# 0     2.379082     CRIM
# 1     2.891900       ZN
# 2    15.910622    INDUS
# 3     1.144417     CHAS
# 4    94.238331      NOX
# 5    74.965902       RM
# 6    24.315139      AGE
# 7    16.620893      DIS
# 8    13.176547      RAD
# 9    55.216435      TAX
# 10  103.498260  PTRATIO
# 11   27.708427        B
# 12   11.556215    LSTAT

# %% [markdown]
# There is no hard and fast rules on VIF factors, while a score above 10 is undesirable as it suggests very correlation that artificially inflates our R score, a subjective call must be taken depending on the problem. For example, while the TAX variable (full-value property-tax rate per 10,000 dollars) is highly correlated with the rest of the variables, it is too important of a variable to ignore, plus it is very significant at the 5% level.
#
# NOX and INDUS on the other hand, we can try and remove and see if we get a better model. Let's re-create our training sets.

# %%
#create second training set
#df = df.drop(["NOX","INDUS"], axis = 1)
X_train1, X_test1, Y_train1, Y_test1 = train_test_split(df, target, test_size=0.30)
print(df.shape)
print(X_test1.shape)
# Out:
# (506, 13)
# (152, 13)

# %%
# fit second model
model_2 = smf.OLS(Y_train1,X_train1).fit()
prediction_3 = model_2.predict(X_train1)# predict y_test values
prediction_4 = model_2.predict(X_test1)# predict y_test values

# %%
model_2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   MEDV   R-squared:                       0.956
# Model:                            OLS   Adj. R-squared:                  0.955
# Method:                 Least Squares   F-statistic:                     572.8
# Date:                Sat, 13 Jan 2018   Prob (F-statistic):          1.28e-222
# Time:                        08:49:07   Log-Likelihood:                -1076.9
# No. Observations:                 354   AIC:                             2180.
# Df Residuals:                     341   BIC:                             2230.
# Df Model:                          13
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# CRIM          -0.0771      0.040     -1.937      0.054      -0.155       0.001
# ZN             0.0640      0.018      3.476      0.001       0.028       0.100
# INDUS          0.0220      0.086      0.254      0.799      -0.148       0.192
# CHAS           2.1627      1.089      1.987      0.048       0.022       4.304
# NOX           -5.3397      4.165     -1.282      0.201     -13.532       2.852
# RM             5.7551      0.380     15.141      0.000       5.007       6.503
# AGE         -5.18e-05      0.017     -0.003      0.998      -0.033       0.033
# DIS           -1.0458      0.249     -4.197      0.000      -1.536      -0.556
# RAD            0.1849      0.082      2.246      0.025       0.023       0.347
# TAX           -0.0110      0.005     -2.136      0.033      -0.021      -0.001
# PTRATIO       -0.3015      0.138     -2.187      0.029      -0.573      -0.030
# B              0.0160      0.003      5.036      0.000       0.010       0.022
# LSTAT         -0.3832      0.059     -6.497      0.000      -0.499      -0.267
# ==============================================================================
# Omnibus:                      144.226   Durbin-Watson:                   1.873
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              861.970
# Skew:                           1.599   Prob(JB):                    6.69e-188
# Kurtosis:                       9.944   Cond. No.                     8.58e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 8.58e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
rmse_training_2 = sqrt(mean_squared_error(Y_train1, prediction_3))
print("RMSE for training data:", rmse_training)
rmse_test_2 = sqrt(mean_squared_error(Y_test1,prediction_4))
print("RMSE for test data:", rmse_test)
# Out:
# RMSE for training data: 4.611418758222202
# RMSE for test data: 5.6805635320450865

# %%
lm = linear_model.LinearRegression()
model_2 = lm.fit(X_train,Y_train)

# %%
rms = sqrt(mean_squared_error(Y_test, prediction_2))
print("RMSE_test:",rms)
rms_1 = sqrt(mean_squared_error(Y_train,prediction_1))
print("RMSE_train:",rms_1)
# Out:
# RMSE_test: 5.6805635320450865
# RMSE_train: 4.611418758222202

# %%
residual = Y_test.values-prediction_2
#print(residual)
for i in X_test:
    plt.scatter(X_test[i],residual)
    plt.xlim(0,)
    plt.xlabel(i)
    plt.ylabel("residuals")
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-15-010e95fe31a2> in <module>()
# ----> 1 residual = Y_test.values-prediction_2
#       2 #print(residual)
#       3 for i in X_test:
#       4     plt.scatter(X_test[i],residual)
#       5     plt.xlim(0,)
#
# /usr/local/lib/python3.5/dist-packages/pandas/core/ops.py in wrapper(left, right, name, na_op)
#     743             index=left.index,
#     744             name=name,
# --> 745             dtype=dtype,
#     746         )
#     747
#
# /usr/local/lib/python3.5/dist-packages/pandas/core/ops.py in _construct_result(left, result, index, name, dtype)
#     651
#     652 def _construct_result(left, result, index, name, dtype):
# --> 653     return left._constructor(result, index=index, name=name, dtype=dtype)
#     654
#     655
#
# /usr/local/lib/python3.5/dist-packages/pandas/core/series.py in __init__(self, data, index, dtype, name, copy, fastpath)
#     262             else:
#     263                 data = _sanitize_array(data, index, dtype, copy,
# --> 264                                        raise_cast_failure=True)
#     265
#     266                 data = SingleBlockManager(data, index, fastpath=True)
#
# /usr/local/lib/python3.5/dist-packages/pandas/core/series.py in _sanitize_array(data, index, dtype, copy, raise_cast_failure)
#    3232     elif subarr.ndim > 1:
#    3233         if isinstance(data, np.ndarray):
# -> 3234             raise Exception('Data must be 1-dimensional')
#    3235         else:
#    3236             subarr = _asarray_tuplesafe(data, dtype=dtype)
#
# Exception: Data must be 1-dimensional

# %% [markdown]
# ## Test for Heteroskedacticity (Breush-Pagan)

# %%
name = [ 'p-value']
test = smf.het_breuschpagan(model_1.resid, model_1.model.exog)
lzip(name, test)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-16-3587dfdac51d> in <module>()
#       1 name = [ 'p-value']
# ----> 2 test = smf.het_breuschpagan(model_1.resid, model_1.model.exog)
#       3 lzip(name, test)
#
# AttributeError: module 'statsmodels.formula.api' has no attribute 'het_breuschpagan'

# %% [markdown]
# ## POLYNOMIAL TEST

# %%
# Import
# %matplotlib inline

from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
import statsmodels.api as sm
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error

import pandas as pd


#prices = df['MEDV']
prices = pd.DataFrame(boston.target, columns=["MEDV"])
df.head()

df1 = df[6:8]
df2 = df[11:12]
df3 = df[13:]

features = pd.concat([df1, df2, df3], axis=1)


for i in features:
    x= df[i]
    y = prices
    plt.scatter(x,y)
    plt.xlim(0,)
    plt.xlabel(i)
    plt.ylabel("Prices")
    #plt.show()

    
# i: index
plt.figure(figsize=(20, 5))
for i, col in enumerate(features.columns):
    # 3 plots here hence 1, 3
    plt.subplot(1, 3, i+1)
    x = df[col]
    y = prices
    plt.plot(x, y, 'o')
    # Create regression line
    plt.plot(np.unique(x), np.poly1d(np.polyfit(x, y, 1), True)(np.unique(x)))
    plt.title(col)
    plt.xlabel(col)
    plt.ylabel('prices')
# Out:
# /usr/local/lib/python3.5/dist-packages/statsmodels/compat/pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-96a72a032aba> in <module>()
#      13
#      14 #prices = df['MEDV']
# ---> 15 prices = pd.DataFrame(boston.target, columns=["MEDV"])
#      16 df.head()
#      17
#
# NameError: name 'boston' is not defined

# %%
#prices = df['MEDV']
prices = pd.DataFrame(boston.target, columns=["MEDV"])

df1 = df[df.columns[5:7]] 
df2 = df[df.columns[10:11]]
df3 = df[df.columns[12:13]]
features = pd.concat([df1, df2, df3], axis=1)

prices.isnull().sum
prices.dropna(axis=1, how='all')
#pr = prices[:-10] # drop rows to the end
#prices.drop(prices.index[[497,10]])
#prices.index[[497,10]]

x_train,x_test,y_train,y_test = train_test_split(features, prices,test_size = 0.2)
features.head()

#df.head()
# Out:
#       RM   AGE  PTRATIO  LSTAT
# 0  6.575  65.2     15.3   4.98
# 1  6.421  78.9     17.8   9.14
# 2  7.185  61.1     17.8   4.03
# 3  6.998  45.8     18.7   2.94
# 4  7.147  54.2     18.7   5.33

# %%
plt.figure(figsize=(20, 5))
for  i, col in enumerate(x_train.columns):
    # 3 plots here hence 1, 3
    plt.subplot(1, 4, i+1)
    x = df[col]
    y = prices
    plt.plot(x, y, 'o')
    plt.title(col)
    plt.xlabel(col)
    plt.ylabel('prices')

# %%
# applying simple OLS
train_model = sm.OLS(y_train, x_train).fit()
train_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   MEDV   R-squared:                       0.954
# Model:                            OLS   Adj. R-squared:                  0.954
# Method:                 Least Squares   F-statistic:                     2075.
# Date:                Sat, 13 Jan 2018   Prob (F-statistic):          6.31e-266
# Time:                        08:49:27   Log-Likelihood:                -1238.9
# No. Observations:                 404   AIC:                             2486.
# Df Residuals:                     400   BIC:                             2502.
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# RM             6.2594      0.252     24.846      0.000       5.764       6.755
# AGE            0.0122      0.012      1.030      0.304      -0.011       0.035
# PTRATIO       -0.5965      0.099     -6.021      0.000      -0.791      -0.402
# LSTAT         -0.5306      0.053    -10.054      0.000      -0.634      -0.427
# ==============================================================================
# Omnibus:                      138.468   Durbin-Watson:                   2.033
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              772.594
# Skew:                           1.350   Prob(JB):                    1.71e-168
# Kurtosis:                       9.213   Cond. No.                         80.9
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
#printing OLS MSE, we will compare this to the next 
y_pred = train_model.predict(x_test)
mse_train = mean_squared_error(y_test, y_pred) 
mse_train
# Out:
# 33.56077689340664

# %%
plt.figure(figsize=(20, 5))
for  i, col in enumerate(x_train.columns):
    # 3 plots here hence 1, 3
    plt.subplot(1, 4, i+1)
    x = df[col]
    #y= [y_train['MEDV']]
    y= prices
    #print(y)
    plt.plot(x, y, 'o')
    plt.title(col)
    plt.xlabel(col)
    plt.ylabel('prices') 
    plt.plot(x_test[col], y_pred, color='red', linewidth=1)

# %% [markdown]
# ## POLYNOMIAL REGRESSION

# %%
# reshaping data to avoid dimensional mismatch
x_train_poly = x_train.values.reshape(-1,1)
x_test_poly = x_test.values.reshape(-1,1)
#print(x_test_poly)

# %%
# PolynomialFeatures (prepreprocessing)
poly = PolynomialFeatures(degree=2)
X_poly = poly.fit_transform(x_train_poly)
X_test_poly = poly.fit_transform(x_test_poly)

# %%
#poly_model = sm.OLS(y_train,X_poly).fit()

X_poly.shape
print(X_poly)
# Out:
# [[  1.00000000e+00   7.80200000e+00   6.08712040e+01]
#  [  1.00000000e+00   9.82000000e+01   9.64324000e+03]
#  [  1.00000000e+00   1.47000000e+01   2.16090000e+02]
#  ...,
#  [  1.00000000e+00   9.54000000e+01   9.10116000e+03]
#  [  1.00000000e+00   1.78000000e+01   3.16840000e+02]
#  [  1.00000000e+00   1.70900000e+01   2.92068100e+02]]

# %%
#notice how the mse reduces
y_pred_poly = poly_model.predict(X_test_poly)
mse_train = mean_squared_error(y_test, y_pred_poly) 
mse_train

# %%
plt.figure(figsize=(20, 5))
for  i, col in enumerate(x_train.columns):
    # 3 plots here hence 1, 3
    plt.subplot(1, 4, i+1)
    x = x_test[col]
    y = prices
    plt.plot(x, y, 'o')
    plt.title(col)
    plt.xlabel(col)
    plt.ylabel('prices') 
    plt.plot(x_test_poly, y_pred_poly, color='red', linewidth=3)
