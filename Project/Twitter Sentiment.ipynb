# %%
from tweepy import Stream
from tweepy import OAuthHandler
from tweepy.streaming import StreamListener
#import MySQLdb
#import time
import json

# %%
#        replace mysql.server with "localhost" if you are running via your own server!
#                        server       MySQL username	MySQL pass  Database name.
#conn = MySQLdb.connect("mysql.server","beginneraccount","cookies","beginneraccount$tutorial")
#c = conn.cursor()



#consumer key, consumer secret, access token, access secret.
ckey="0F5RBbbYw7FUDQxKpXnnfhAbB"
csecret="G5aGZUhqfrqb1lckK1lDyoH20mZBZbJb7eZvG1WX4A8kDizBcl"
atoken="145787533-dI54XaITn1cwhI2PUyQOUQlNPeXAQIE9H6c6JRFl"
asecret="I8bvHVmLZ4fY90JhQe5ur3nq4NIjD2CwCqbbcO7Sg6Wag"

class listener(StreamListener):

    def on_data(self, data):
        all_data = json.loads(data)
        
        tweet = all_data["text"]
        sentiment_value, confidence = s.sentiment(tweet)
        
        #username = all_data["user"]["screen_name"]
        #c.execute("INSERT INTO taula (time, username, tweet) VALUES (%s,%s,%s)",(time.time(), username, tweet))
        #conn.commit()
        #print((username,tweet))
      
        print(tweet, sentiment_value, confidence)
        time.sleep(0.3)
        return True

    def on_error(self, status):
        print(status)

auth = OAuthHandler(ckey, csecret)
auth.set_access_token(atoken, asecret)

twitterStream = Stream(auth, listener())
twitterStream.filter(track=["car"])
# Out:
# RT @charoenpura: มึงเป็นรถEco Carก็จริง แต่ไม่ต้องประหยัดไปยันไฟเลี้ยวก็ได้ อีเวง
# RT @AU_PSD: African Initiative is central in supporting the people of #CAR in their quest for PEACE and Reconciliation –Amb. Catherine M. M…
# Picking your wedding car but can't decide?
# Here's some great blog posts from Wedding Ideas magazine .
#
# https://t.co/AHfY7N4nDu
# Solo te falta ponerte una peluca y hacer vídeos en yutub... https://t.co/pvNbu2UCzB
# RT @aliotcard: this is how riku is gonna rescue aqua in the realm of darkness after getting his new car key #kh3 https://t.co/NjvkbQWel5
# What a pretty car😍 kinda bias, kinda not. https://t.co/RU0CIPtRVG
# RT @cassana_: "Querer a las personas como se quiere a un gato, con su carácter y su independencia, sin intentar domarlo, sin intentar cambi…
# RT @marclahen: CSG retraites couple: 65,41+59,97= 125,48€/ mois =1505,76€ /an soit 1 taxe d’habitation en+ car serons ds les 20% “nantis” j…
# ...
